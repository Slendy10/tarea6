# %%
import math

# %%
import poblacionesmendelianas as pobla

# %%
# !pip install scipy

# %%
import scipy

# %%
pobla.build_population(N = 499, p = 0.48)
# Out:
# [('a', 'A'),
#  ('a', 'A'),
#  ('a', 'a'),
#  ('A', 'A'),
#  ('a', 'a'),
#  ('a', 'A'),
#  ('A', 'a'),
#  ('a', 'a'),
#  ('A', 'A'),
#  ('A', 'a'),
#  ('A', 'a'),
#  ('a', 'a'),
#  ('a', 'A'),
#  ('A', 'A'),
#  ('A', 'A'),
#  ('A', 'A'),
#  ('a', 'a'),
#  ('a', 'A'),
#  ('A', 'a'),
#  ('A', 'A'),
#  ('A', 'a'),
#  ('A', 'a'),
#  ('a', 'A'),
#  ('A', 'A'),
#  ('a', 'A'),
#  ('A', 'a'),
#  ('A', 'a'),
#  ('A', 'A'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('A', 'a'),
#  ('A', 'a'),
#  ('a', 'a'),
#  ('A', 'a'),
#  ('a', 'a'),
#  ('A', 'a'),
#  ('a', 'A'),
#  ('a', 'A'),
#  ('A', 'a'),
#  ('a', 'A'),
#  ('a', 'a'),
#  ('a', 'A'),
#  ('a', 'a'),
#  ('a', 'A'),
#  ('a', 'A'),
#  ('A', 'a'),
#  ('a', 'A'),
#  ('A', 'a'),
#  ('a', 'a'),
#  ('a', 'A'),
#  ('A', 'A'),
#  ('A', 'a'),
#  ('a', 'A'),
#  ('a', 'A'),
#  ('A', 'A'),
#  ('A', 'a'),
#  ('A', 'A'),
#  ('A', 'a'),
#  ('a', 'A'),
#  ('A', 'a'),
#  ('A', 'a'),
#  ('a', 'A'),
#  ('a', 'A'),
#  ('a', 'A'),
#  ('A', 'A'),
#  ('a', 'a'),
# ...

# %%
my_pop= pobla.build_population(500, 0.21)
print(my_pop)
# Out:
# [('a', 'a'), ('a', 'a'), ('a', 'a'), ('a', 'A'), ('A', 'a'), ('a', 'A'), ('a', 'a'), ('a', 'a'), ('a', 'a'), ('a', 'a'), ('a', 'A'), ('a', 'a'), ('a', 'a'), ('A', 'A'), ('a', 'a'), ('a', 'A'), ('A', 'a'), ('A', 'A'), ('A', 'A'), ('a', 'A'), ('a', 'a'), ('a', 'a'), ('a', 'a'), ('A', 'a'), ('a', 'a'), ('a', 'a'), ('a', 'a'), ('a', 'a'), ('a', 'a'), ('a', 'A'), ('a', 'a'), ('a', 'A'), ('a', 'a'), ('a', 'A'), ('a', 'A'), ('a', 'a'), ('a', 'a'), ('a', 'a'), ('a', 'a'), ('a', 'A'), ('a', 'A'), ('a', 'A'), ('A', 'a'), ('a', 'a'), ('a', 'a'), ('a', 'a'), ('a', 'a'), ('A', 'a'), ('a', 'a'), ('a', 'a'), ('A', 'A'), ('a', 'a'), ('a', 'A'), ('A', 'a'), ('a', 'a'), ('a', 'a'), ('a', 'A'), ('a', 'a'), ('a', 'a'), ('a', 'A'), ('a', 'a'), ('a', 'a'), ('A', 'a'), ('a', 'a'), ('A', 'a'), ('a', 'a'), ('a', 'a'), ('a', 'a'), ('a', 'a'), ('a', 'a'), ('a', 'a'), ('a', 'a'), ('A', 'a'), ('a', 'a'), ('a', 'a'), ('a', 'a'), ('a', 'A'), ('A', 'a'), ('a', 'a'), ('a', 'a'), ('a', 'a'), ('a', 'a'), ('a', 'a'), (
# ...

# %%
fmy_pop = pobla.compute_frequencies(my_pop)
print(fmy_pop)
print((500-fmy_pop["aa"])/500) # es la proporción despues de sacar los resecivos "aa"
# Out:
# {'AA': 29, 'aa': 294, 'Aa': 99, 'aA': 78}
# 0.41082164328657317

# %%
fmy_pop = pobla.compute_frequencies(my_pop)
print(fmy_pop)
# Out:
# {'AA': 29, 'aa': 294, 'Aa': 99, 'aA': 78}

# %%
new_pop = pobla.reproduce_population(my_pop)
print(new_pop)
# Out:
# [('A', 'A'), ('a', 'a'), ('A', 'A'), ('a', 'a'), ('a', 'a'), ('a', 'A'), ('A', 'a'), ('A', 'a'), ('a', 'A'), ('a', 'a'), ('a', 'a'), ('A', 'a'), ('A', 'a'), ('a', 'a'), ('a', 'a'), ('a', 'a'), ('a', 'a'), ('A', 'a'), ('a', 'a'), ('a', 'a'), ('A', 'a'), ('a', 'a'), ('a', 'a'), ('a', 'a'), ('a', 'a'), ('A', 'a'), ('a', 'a'), ('a', 'a'), ('a', 'a'), ('a', 'a'), ('a', 'A'), ('a', 'a'), ('A', 'A'), ('a', 'a'), ('a', 'a'), ('A', 'a'), ('a', 'a'), ('a', 'a'), ('A', 'A'), ('a', 'A'), ('a', 'a'), ('A', 'a'), ('a', 'A'), ('A', 'a'), ('a', 'a'), ('A', 'a'), ('A', 'a'), ('A', 'a'), ('A', 'a'), ('a', 'A'), ('a', 'a'), ('a', 'A'), ('a', 'a'), ('a', 'a'), ('a', 'a'), ('a', 'a'), ('A', 'a'), ('A', 'a'), ('a', 'A'), ('a', 'a'), ('a', 'a'), ('a', 'a'), ('a', 'a'), ('a', 'a'), ('A', 'a'), ('A', 'A'), ('a', 'a'), ('a', 'a'), ('a', 'a'), ('a', 'a'), ('a', 'a'), ('a', 'a'), ('a', 'a'), ('a', 'a'), ('a', 'a'), ('a', 'a'), ('A', 'a'), ('a', 'A'), ('a', 'A'), ('a', 'a'), ('a', 'a'), ('a', 'A'), ('a', 'A'), (
# ...

# %%
new_pop2 = pobla.reproduce_population(new_pop)
print(new_pop2)
# Out:
# [('a', 'a'), ('a', 'A'), ('a', 'a'), ('a', 'a'), ('a', 'a'), ('a', 'a'), ('a', 'a'), ('a', 'a'), ('A', 'a'), ('a', 'a'), ('a', 'a'), ('A', 'a'), ('a', 'a'), ('a', 'a'), ('a', 'a'), ('a', 'a'), ('A', 'a'), ('a', 'a'), ('a', 'a'), ('a', 'a'), ('a', 'a'), ('a', 'A'), ('A', 'a'), ('a', 'a'), ('a', 'a'), ('a', 'a'), ('a', 'a'), ('a', 'A'), ('a', 'A'), ('a', 'a'), ('a', 'a'), ('a', 'a'), ('a', 'a'), ('a', 'a'), ('a', 'a'), ('a', 'a'), ('a', 'a'), ('A', 'a'), ('a', 'a'), ('a', 'a'), ('A', 'a'), ('a', 'a'), ('a', 'a'), ('a', 'a'), ('a', 'A'), ('a', 'a'), ('A', 'A'), ('A', 'a'), ('a', 'a'), ('A', 'a'), ('a', 'a'), ('a', 'a'), ('a', 'a'), ('a', 'a'), ('a', 'A'), ('a', 'a'), ('A', 'a'), ('A', 'a'), ('a', 'a'), ('a', 'a'), ('a', 'A'), ('a', 'A'), ('a', 'A'), ('A', 'a'), ('A', 'a'), ('a', 'a'), ('a', 'a'), ('a', 'A'), ('A', 'a'), ('a', 'a'), ('a', 'a'), ('A', 'a'), ('a', 'a'), ('a', 'a'), ('a', 'a'), ('a', 'a'), ('A', 'A'), ('A', 'a'), ('a', 'a'), ('a', 'a'), ('a', 'a'), ('a', 'a'), ('a', 'A'), (
# ...
